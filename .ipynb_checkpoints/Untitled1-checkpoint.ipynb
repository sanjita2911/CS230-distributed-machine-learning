# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       3 import matplotlib.pyplot as plt
#       5 # Load your metrics JSON lines
# ----> 6 with open('metrics_raw.json', 'r') as f:
#       7     records = [json.loads(line) for line in f]
#       9 df = pd.DataFrame(records)
#
# File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'metrics_raw.json'

# %%
pwd
# Out:
# '/Users/sanjitanayak/Desktop/Projects/CS230-distributed-machine-learning'

# %%
cd ..
# Out:
# /Users/sanjitanayak/Desktop/Projects

# %%
 cd ..
# Out:
# /Users/sanjitanayak/Desktop

# %%
ls
# Out:
# Projects/
# Screenshot 2025-04-30 at 8.04.20 PM.png
# Screenshot 2025-05-05 at 8.56.17 PM.png
# Screenshot 2025-05-07 at 5.31.15 PM.png
# Screenshot 2025-05-07 at 5.34.54 PM.png
# Screenshot 2025-05-07 at 5.38.28 PM.png
# Screenshot 2025-05-19 at 10.26.14 AM.png
# Screenshot 2025-05-19 at 3.43.46 PM.png
# Screenshot 2025-05-19 at 5.13.37 PM.png
# Screenshot 2025-05-19 at 6.49.26 PM.png
# Screenshot 2025-05-19 at 6.49.51 PM.png
# Screenshot 2025-05-19 at 6.50.03 PM.png
# Screenshot 2025-05-19 at 7.20.41 PM.png
# Screenshot 2025-05-19 at 7.21.22 PM.png
# Screenshot 2025-05-19 at 7.21.38 PM.png
# Screenshot 2025-05-19 at 7.39.10 PM.png
# Screenshot 2025-05-20 at 11.44.21 AM.png
# Screenshot 2025-05-24 at 12.00.36 AM.png
# Screenshot 2025-05-24 at 12.22.07 PM.png
# Screenshot 2025-05-25 at 12.31.44 PM.png
# aws-prod/
# doc? (3) - JupyterLab.pdf

# %%
cd ..
# Out:
# /Users/sanjitanayak

# %%
ls
# Out:
# Applications/         Untitled12.ipynb      cs257_code.ipynb
# Cs257_final.ipynb     Untitled13.ipynb      cs257_code_hw2.ipynb
# Desktop/              Untitled14.ipynb      cs257_hw4_2.ipynb
# Documents/            Untitled15.ipynb      cs257_hw4_3.ipynb
# Downloads/            Untitled16.ipynb      data/
# Library/              Untitled17.ipynb      deepseek.ipynb
# Movies/               Untitled2.ipynb       eclipse/
# Music/                Untitled3.ipynb       eclipse-workspace/
# Pictures/             Untitled4.ipynb       go/
# Postman/              Untitled5.ipynb       last.ipynb
# Public/               Untitled6.ipynb       metrics_raw.json
# Question_3.ipynb      Untitled7.ipynb       old_code.ipynb
# Untitled.ipynb        Untitled8.ipynb       scikit_learn_data/
# Untitled1.ipynb       Untitled9.ipynb       test.ipynb
# Untitled10.ipynb      backup.ipynb
# Untitled11.ipynb      cs217_hw2.ipynb

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# 1) Load and fix timestamps
records = []
with open('metrics_raw.json','r') as f:
    for line in f:
        rec = json.loads(line)
        for ts in ('started_at','finished_at'):
            rec[ts] = rec[ts].rstrip('Z')
        records.append(rec)

df = pd.DataFrame(records)
df['started_at'] = pd.to_datetime(df['started_at'], utc=True)
df['finished_at'] = pd.to_datetime(df['finished_at'], utc=True)

# 2) Compute execution duration in seconds
df['exec_secs'] = (df['finished_at'] - df['started_at']).dt.total_seconds()

# 3) We want a continuous time axis: convert times to matplotlib dates
df['start_num'] = mdates.date2num(df['started_at'])
df['end_num']   = mdates.date2num(df['finished_at'])

# 4) Assign each worker an integer y-position
workers = sorted(df['worker_id'].unique())
worker_to_y = {w: i for i,w in enumerate(workers)}
df['y'] = df['worker_id'].map(worker_to_y)

# 5) Plot: each subtask as a colored horizontal bar from start→end on its worker row
fig, ax = plt.subplots(figsize=(12, 6))

# Choose a colormap for exec_secs (longer = brighter)
cmap = plt.get_cmap('Reds')

for _, row in df.iterrows():
    ax.barh(
        y=row['y'],
        width=(row['end_num'] - row['start_num']),
        left=row['start_num'],
        height=0.8,
        color=cmap(row['exec_secs'] / df['exec_secs'].max()),
        edgecolor='none'
    )

# 6) Formatting
ax.set_yticks(range(len(workers)))
ax.set_yticklabels(workers)
ax.set_xlabel('Time')
ax.set_ylabel('Worker ID')
ax.set_title('Worker Execution Timeline (color = relative exec duration)')

# Format x-axis as HH:MM:SS
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))

plt.tight_layout()
plt.show()
